# %%
# -*- coding: utf-8 -*- 
import numpy as np
import pandas as pd

# %%
headername = ['user_id', 'gender','age','job','zipcode']
df1 = pd.read_table('users.dat', sep='::', header=None,names=headername,engine='python')
df1.index +=1
df1.to_csv('users.csv', sep=',', index_label='id',encoding='utf-8')

# %%
('é').encode('utf-8')
# Out:
# b'\xc3\xa9'

# %%
headername = ['movieid', 'title', 'genre']
df1 = pd.read_table('movies.dat', sep='::', header=None,names=headername,engine='python',encoding='cp850')
df1.index +=1
df1.to_csv('movies.csv', sep=',', index=False,encoding='cp850')

# %%
len(df1.movieid.unique())
# Out:
# 3883

# %%
headernames = ['user_id', 'movie_id', 'rating', 'time']
df = pd.read_table('ratings.dat', sep='::', header=None,names=headernames,engine='python')
df.index +=1

df.to_csv('ratings.csv', sep=',',index =False,encoding='utf-8')

# %%
len(df.movie_id.unique())
# Out:
# 3706

# %%
# Out:
# 1

# %%
n_users = data.user_id.unique().shape[0]


print(n_users)
n_items = df.item_id.unique().shape[0]
print ('Number of users = '+ str(n_users) + ' | Number of movies = ' + str(n_items))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-168-b621a89d7f44> in <module>()
# ----> 1 n_users = data.user_id.unique().shape[0]
#       2
#       3
#       4 print(n_users)
#       5 n_items = df.item_id.unique().shape[0]
#
# AttributeError: 'list' object has no attribute 'user_id'

# %%
from sklearn import model_selection as cv
train_data, test_data = cv.train_test_split(df, test_size=0.25)

# %%
#Create two user-item matrices, one for training and another for testing
train_data_matrix = np.zeros((n_users, n_items))
for line in train_data.itertuples():
    train_data_matrix[line[1]-1, line[2]-1] = line[3]  
    
test_data_matrix = np.zeros((n_users, n_items))
for line in test_data.itertuples():
    test_data_matrix[line[1]-1, line[2]-1] = line[3]
from sklearn.metrics.pairwise import pairwise_distances
user_similarity = pairwise_distances(train_data_matrix, metric='cosine')
item_similarity = pairwise_distances(train_data_matrix.T, metric='cosine')

# %%
def predict(ratings, similarity, type='user'):
        if type == 'user':
            mean_user_rating = ratings.mean(axis=1)
            #You use np.newaxis so that mean_user_rating has same format as ratings
            ratings_diff = (ratings - mean_user_rating[:, np.newaxis]) 
            pred = mean_user_rating[:, np.newaxis] + similarity.dot(ratings_diff) / np.array([np.abs(similarity).sum(axis=1)]).T
        elif type == 'item':
            pred = ratings.dot(similarity) / np.array([np.abs(similarity).sum(axis=1)])     
        return pred

# %%
item_prediction = predict(train_data_matrix, item_similarity, type='item')
user_prediction = predict(train_data_matrix, user_similarity, type='user')

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
def rmse(prediction, ground_truth):
    prediction = prediction[ground_truth.nonzero()].flatten() 
    ground_truth = ground_truth[ground_truth.nonzero()].flatten()
    return sqrt(mean_squared_error(prediction, ground_truth))

# %%
print ('User-based CF RMSE: ' + str(rmse(user_prediction, test_data_matrix)))
print ('Item-based CF RMSE: ' + str(rmse(item_prediction, test_data_matrix)))
# Out:
# User-based CF RMSE: 3.113640331420135
# Item-based CF RMSE: 3.440353211428457

# %%
import random
y=list(range(0,10))
slice = random.sample(y, 5)
slice
# Out:
# [6, 1, 8, 2, 7]

# %%
import os
Path=' /Users/ghh/Desktop/Tomorrowland-2014.mp4'
os.system("open"+Path)
# Out:
# 0

# %%
from imdbpie import Imdb
from urllib.request import urlretrieve
imdb = Imdb()
         # import requests
data=imdb.search_for_title('Orlando (1993)')

# %%
info=imdb.get_title(data[0]['imdb_id'])

# %%
info
# Out:
# {'@type': 'imdb.api.title.auxiliary.v1',
#  'base': {'id': '/title/tt0255451/',
#   'title': 'Orlando',
#   'titleType': 'tvMovie',
#   'year': 1993},
#  'metacriticScore': {'@type': 'imdb.api.title.metacritic.score',
#   'reviewCount': 0,
#   'userRatingCount': 0},
#  'ratings': {'canRate': True,
#   'id': '/title/tt0255451/',
#   'title': 'Orlando',
#   'titleType': 'tvMovie',
#   'year': 1993}}

# %%
info.keys()
# Out:
# dict_keys(['@type', 'base', 'filmingLocations', 'metacriticScore', 'plot', 'ratings', 'similarities', 'soundtrack'])

# %%
info1=imdb.get_title_credits(data[0]['imdb_id'])

# %%
info1
# Out:
# {'@type': 'imdb.api.title.credits',
#  'base': {'id': '/title/tt1375666/',
#   'image': {'height': 1037,
#    'id': '/title/tt1375666/images/rm3426651392',
#    'url': 'https://ia.media-imdb.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_.jpg',
#    'width': 700},
#   'runningTimeInMinutes': 148,
#   'title': 'Inception',
#   'titleType': 'movie',
#   'year': 2010},
#  'credits': {'art_department': [{'category': 'art_department',
#     'id': '/name/nm2241231/',
#     'job': 'set decoration coordinator',
#     'legacyNameText': 'Adkins, Charlsey',
#     'name': 'Charlsey Adkins'},
#    {'category': 'art_department',
#     'id': '/name/nm0021423/',
#     'job': 'prop shop supervisor',
#     'legacyNameText': 'Allison, Damon',
#     'name': 'Damon Allison'},
#    {'akas': ['Richard Andrade'],
#     'category': 'art_department',
#     'id': '/name/nm0028092/',
#     'job': 'set dresser',
#     'legacyNameText': 'Andrade, Rich',
#     'name': 'Rich Andrade'},
# ...

# %%
info1['credits']
# Out:
# {'art_department': [{'category': 'art_department',
#    'id': '/name/nm2241231/',
#    'job': 'set decoration coordinator',
#    'legacyNameText': 'Adkins, Charlsey',
#    'name': 'Charlsey Adkins'},
#   {'category': 'art_department',
#    'id': '/name/nm0021423/',
#    'job': 'prop shop supervisor',
#    'legacyNameText': 'Allison, Damon',
#    'name': 'Damon Allison'},
#   {'akas': ['Richard Andrade'],
#    'category': 'art_department',
#    'id': '/name/nm0028092/',
#    'job': 'set dresser',
#    'legacyNameText': 'Andrade, Rich',
#    'name': 'Rich Andrade'},
#   {'akas': ['Arcadio Dyas Dominique',
#     'Dominique Arcadio Dyas',
#     'Dominique Dyas'],
#    'category': 'art_department',
#    'id': '/name/nm0033488/',
#    'job': 'art researcher',
#    'legacyNameText': 'Arcadio, Dominique',
#    'name': 'Dominique Arcadio'},
#   {'akas': ['Baadil Abdellah'],
#    'category': 'art_department',
#    'id': '/name/nm1929525/',
#    'job': 'assistant art director',
# ...

# %%
info1['credits']
# Out:
# {'art_department': [{'category': 'art_department',
#    'id': '/name/nm2241231/',
#    'job': 'set decoration coordinator',
#    'legacyNameText': 'Adkins, Charlsey',
#    'name': 'Charlsey Adkins'},
#   {'category': 'art_department',
#    'id': '/name/nm0021423/',
#    'job': 'prop shop supervisor',
#    'legacyNameText': 'Allison, Damon',
#    'name': 'Damon Allison'},
#   {'akas': ['Richard Andrade'],
#    'category': 'art_department',
#    'id': '/name/nm0028092/',
#    'job': 'set dresser',
#    'legacyNameText': 'Andrade, Rich',
#    'name': 'Rich Andrade'},
#   {'akas': ['Arcadio Dyas Dominique',
#     'Dominique Arcadio Dyas',
#     'Dominique Dyas'],
#    'category': 'art_department',
#    'id': '/name/nm0033488/',
#    'job': 'art researcher',
#    'legacyNameText': 'Arcadio, Dominique',
#    'name': 'Dominique Arcadio'},
#   {'akas': ['Baadil Abdellah'],
#    'category': 'art_department',
#    'id': '/name/nm1929525/',
#    'job': 'assistant art director',
# ...

# %%
info2=imdb.get_title_top_crew(data[0]['imdb_id'])

# %%
info2
# Out:
# {'directors': [{'akas': ['Chris Nolan'],
#    'category': 'director',
#    'disambiguation': 'I',
#    'id': '/name/nm0634240/',
#    'image': {'height': 400,
#     'id': '/name/nm0634240/images/rm2047771392',
#     'url': 'https://ia.media-imdb.com/images/M/MV5BNjE3NDQyOTYyMV5BMl5BanBnXkFtZTcwODcyODU2Mw@@._V1_.jpg',
#     'width': 289},
#    'legacyNameText': 'Nolan, Christopher (I)',
#    'name': 'Christopher Nolan'}],
#  'writers': [{'akas': ['Chris Nolan'],
#    'category': 'writer',
#    'disambiguation': 'I',
#    'id': '/name/nm0634240/',
#    'image': {'height': 400,
#     'id': '/name/nm0634240/images/rm2047771392',
#     'url': 'https://ia.media-imdb.com/images/M/MV5BNjE3NDQyOTYyMV5BMl5BanBnXkFtZTcwODcyODU2Mw@@._V1_.jpg',
#     'width': 289},
#    'job': 'written by',
#    'legacyNameText': 'Nolan, Christopher (I)',
#    'name': 'Christopher Nolan',
#    'writerCategoryBilling': 1,
#    'writerTeamBilling': 1}]}

# %%
from imdb import IMDb
ia=IMDb()
movies = ia.search_movie('Fluke (1995)')
movie = movies[0]

# %%
movie.movieID
m  = ia.get_movie(movie.movieID)

# %%
m['full-size cover url']
# Out:
# 'https://ia.media-imdb.com/images/M/MV5BODM0ZTQ2ZGYtNmNlMi00OGU3LTgyMjQtYmVlOGNlYWQ2Y2Y3L2ltYWdlXkEyXkFqcGdeQXVyNjg4NzYzMzA@._V1_SY150_CR0,0,101,150_.jpg'

# %%
' '.join(m['plot outline'].split()[:50])
# Out:
# "Dom Cobb is a skilled thief, the absolute best in the dangerous art of extraction, stealing valuable secrets from deep within the subconscious during the dream state, when the mind is at its most vulnerable. Cobb's rare ability has made him a coveted player in this treacherous new world of"

# %%
cast=','.join([casting['name'] for casting in m['cast'][:4]])
cast
# Out:
# 'Leonardo DiCaprio,Joseph Gordon-Levitt,Ellen Page,Tom Hardy'

# %%
D=','.join([d['name'] for d in m['director']])
D
# Out:
# 'Christopher Nolan'

# %%
s ="fdfdfdf(123)fdfdf(kjkjk)"

# %%
Fluke (1995)
# Out:
# 'fdfdfdf(kjkjk)'
